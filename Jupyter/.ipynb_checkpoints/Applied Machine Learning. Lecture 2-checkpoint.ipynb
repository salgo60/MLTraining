# %% [markdown]
# * video [Applied Machine Learning. Lecture 2 - Part 1: A Supervised Machine Learning Problem](https://youtu.be/UQFlSs3pu-k?t=420)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
#load diabetes information
diabetes_X , diabetes_y = datasets.load_diabetes(return_X_y=True, as_frame=True)

# %%
diabetes_X = diabetes_X.loc[:,['bmi']]

# %%
diabetes_X = diabetes_X * 30 + 25

# %%
#Collect 20 datapoints
diabetes_X_train = diabetes_X.loc[-20:] 
diabetes_y_train = diabetes_y.loc[-20:]

# %%
#Display some datapoint
pd.concat([diabetes_X_train, diabetes_y_train],axis=1).head()
# Out:
#          bmi  target
# 0  26.850886   151.0
# 1  23.455778    75.0
# 2  26.333536   141.0
# 3  24.652150   206.0
# 4  23.908459   135.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,4]
plt.scatter(diabetes_X_train,diabetes_y_train,color='black')
plt.xlabel("Body mass index")
plt.ylabel("Diabetes Risk")
# Out:
# Text(0, 0.5, 'Diabetes Risk')

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
# %config Completer.use_jedi = False
# create linear regression object
regr = linear_model.LinearRegression()

# Train the model using training sets
regr.fit(diabetes_X_train,diabetes_y_train.values)

#Make predictions on the training sets
diabetes_y_train_pred = regr.predict(diabetes_X_train)

#The coefficient
print("Slope (theta1):\t", regr.coef_[0])
print("Intercept (theta1):\t", regr.intercept_)
# Out:
# Slope (theta1):	 31.647842012798296
# Intercept (theta1):	 -639.0625661570607

# %%
plt.xlabel("Body mass index (BMI)")
plt.ylabel("Diabetes Risk")
plt.scatter(diabetes_X_train,diabetes_y_train)
plt.plot(diabetes_X_train,diabetes_y_train_pred,color="black",linewidth=2)

# %%
diabetes_X_test = diabetes_X.loc[:3] 
diabetes_y_test = diabetes_y.loc[:3] 
plt.scatter(diabetes_X_train,diabetes_y_train)
plt.scatter(diabetes_X_test,diabetes_y_test,color="red")
plt.xlabel("Body mass index (BMI)")
plt.ylabel("Diabetes Risk")
plt.legend(["Initial patients","New patients"])

# %%
diabetes_y_test_pred = regr.predict(diabetes_X_test )

plt.scatter(diabetes_X_train,diabetes_y_train)
plt.scatter(diabetes_X_test,diabetes_y_test,color="red",marker="o")
plt.plot(diabetes_X_train,diabetes_y_train_pred,color="black",linewidth=1)
plt.plot(diabetes_X_test,diabetes_y_test_pred,"x",color="red",mew=3,markersize=10)
plt.xlabel("Body mass index (BMI)")
plt.ylabel("Diabetes Risk")
plt.legend(["Model","Prediction","Initial patients","New patients"])

# %% [markdown]
# * part 2 [video](https://www.youtube.com/watch?v=PK6IEeAWiRg)

# %%
diabetes = datasets.load_diabetes(as_frame=True)
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, T-Cells (a type of white blood cells)
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, thyroid stimulating hormone
#       - s5      ltg, lamotrigine
# ...

# %%
diabetes.data.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
diabetes.data.iloc[1]
# Out:
# age   -0.001882
# sex   -0.044642
# bmi   -0.051474
# bp    -0.026328
# s1    -0.008449
# s2    -0.019163
# s3     0.074412
# s4    -0.039493
# s5    -0.068330
# s6    -0.092204
# Name: 1, dtype: float64

# %% [markdown]
# * [video Applied Machine Learning. Lecture 2. Part 3: Anatomy of Supervised Learning: Learning Algorithms 14:48](https://youtu.be/PED1OYvQUX4?t=888)

# %%
#collect 20 points for training
diabetes_X_train = diabetes_X[-20:]
diabetes_y_train = diabetes_y[-20:]

# %%
#create linear regression
regr = linear_model.LinearRegression()
#train the model using the training set
regr.fit(diabetes_X_train,diabetes_y_train.values)
# Out:
# LinearRegression()

# %%
#Make predictions
diabetes_y_train_pred = regr.predict(diabetes_X_train)

# %%
#collect 3 data points for testing
diabetes_X_test = diabetes_X.iloc[:-3]
diabetes_y_test = diabetes_y.iloc[:-3]
#predict
diabetes_y_test_pred = regr.predict(diabetes_X_test)

# %%
plt.xlabel("Body mass index (BMI)")
plt.ylabel("Diabetes Risk")
plt.legend("1")
plt.scatter(diabetes_X_train.loc[:,['bmi']],diabetes_y_train)
plt.scatter(diabetes_X_test.loc[:,['bmi']],diabetes_y_test,color="red",marker="o")
plt.scatter(diabetes_X_test,diabetes_y_test)
plt.plot(diabetes_X_test.loc[:,['bmi']],diabetes_y_test_pred,"x",color="red")
plt.legend(["model","prediction","Initial patients","New patients"])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
y1 = np.array([1,2,3,4])
y2 = np.array([-1,1,3,5])
print ("Mean square error:\t",mean_squared_error(y1,y2))
print ("Mean absolute error:\t",mean_absolute_error(y1,y2))
# Out:
# Mean square error:	 1.5
# Mean absolute error:	 1.0
