# %% [markdown]
# ## [Box-Cox Transformation: Explained](https://towardsdatascience.com/box-cox-transformation-explained-51d745e34203)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
plt.figure(figsize = (8, 8))
data = np.random.beta(1, 3, 5000)
sns.distplot(data)
plt.show()

# %%
from scipy import stats
tdata = stats.boxcox(data)[0]
plt.figure(figsize = (8, 8))
sns.distplot(tdata)
plt.show()

# %%
stats.boxcox(data)
# Out:
# (array([-0.64721068, -1.15597162, -1.09670777, ..., -1.17635687,
#         -1.62058988, -1.78720973]),
#  0.40233360743812213)
